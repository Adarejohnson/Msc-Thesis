# %%
""" Startintg with Data pre-processing
--- This code will import the numpy and pandas library
 ---- Thos code also loads the fashion dataset given for analysis"""
import pandas as pd
import numpy as np
df= pd.read_csv('/content/30years europena countries co2 emisssion.csv', encoding='latin1')
#df1= pd.read_csv('/content/World-population-by-countries-dataset.csv')
df
# Out:
#              country  Year  CO2 emission (Tons)
# 0            Albania  1990         1.724168e+08
# 1            Albania  1991         1.766451e+08
# 2            Albania  1992         1.791403e+08
# 3            Albania  1993         1.814559e+08
# 4            Albania  1994         1.833685e+08
# ...              ...   ...                  ...
# 1483  United Kingdom  2016         7.669310e+10
# 1484  United Kingdom  2017         7.708067e+10
# 1485  United Kingdom  2018         7.746256e+10
# 1486  United Kingdom  2019         7.783157e+10
# 1487  United Kingdom  2020         7.816115e+10
#
# [1488 rows x 3 columns]

# %%
df_pivot= df.pivot(index='country', columns='Year', values='CO2 emission (Tons)')
df_pivot
# Out:
# Year                            1990          1991          1992  \
# country
# Albania                 1.724168e+08  1.766451e+08  1.791403e+08
# Andorra                 4.067040e+05  8.134080e+05  1.220112e+06
# Armenia                 2.485253e+08  2.558136e+08  2.616766e+08
# Austria                 3.453229e+09  3.518967e+09  3.579204e+09
# Azerbaijan              1.435896e+09  1.485930e+09  1.542105e+09
# Belarus                 3.030869e+09  3.127649e+09  3.216508e+09
# Belgium                 9.076546e+09  9.199924e+09  9.322429e+09
# Bosnia and Herzegovina  4.725771e+08  4.862104e+08  5.012391e+08
# Bulgaria                2.324789e+09  2.386306e+09  2.443671e+09
# Croatia                 4.910077e+08  5.079939e+08  5.243654e+08
# Cyprus                  8.050658e+07  8.564776e+07  9.116362e+07
# Czechia                 8.292873e+09  8.441765e+09  8.586382e+09
# Estonia                 1.088859e+09  1.122682e+09  1.147038e+09
# ...

# %%
# Downloading my cleaned and merged data for big data analysis and power BI visualization
from google.colab import files
# save the file from dataframe to a csv format
df_pivot.to_csv('df_pivot.csv')
# download the file to the download folder in my local drive
files.download('df_pivot.csv')

# %%
df_pivot1 = pd.read_csv('/content/df_pivot1.csv', encoding='latin1')
df_pivot1
# Out:
#            1990         1991         1992         1993         1994  \
# 0     172416848    176645104    179140288    181455936    183368544
# 1        406704       813408      1220112      1630480      2037184
# 2     248525343    255813635    261676574    264251613    266964955
# 3    3453229292   3518967484   3579203940   3639864721   3700899158
# 4    1435896132   1485930108   1542104508   1590510606   1632454510
# 5    3030868628   3127649063   3216507843   3293062884   3355567997
# 6    9076545842   9199924260   9322429144   9443867924   9568675680
# 7     472577076    486210397    501239110    513819686    517024638
# 8    2324788510   2386305794   2443670987   2502096930   2558500875
# 9     491007740    507993929    524365361    541173340    557226117
# 10     80506578     85647758     91163621     96922879    102923528
# 11   8292872672   8441765059   8586382001   8725016270   8857386621
# 12   1088858980   1122682305   1147037564   1166441241   1186477666
# ...

# %%
df_pivot1.index = df_pivot1.index + 1
df_out = df_pivot1.stack()
df_out.index = df_out.index.map('{0[1]}_{0[0]}'.format)
df_pivot2= df_out.to_frame().T
df_pivot2
# Out:
#         1990_1       1991_1       1992_1       1993_1       1994_1  \
# 0  172416848.0  176645104.0  179140288.0  181455936.0  183368544.0
#
#         1995_1       1996_1       1997_1       1998_1       1999_1  ...  \
# 0  185435040.0  187428256.0  188959808.0  190703872.0  193679040.0  ...
#
#         2011_48       2012_48       2013_48       2014_48       2015_48  \
# 0  7.446798e+10  7.495550e+10  7.543288e+10  7.587142e+10  7.629376e+10
#
#         2016_48       2017_48       2018_48       2019_48       2020_48
# 0  7.669310e+10  7.708067e+10  7.746256e+10  7.783157e+10  7.816115e+10
#
# [1 rows x 1488 columns]

# %%
# Downloading my cleaned and merged data for big data analysis and power BI visualization
from google.colab import files
# save the file from dataframe to a csv format
df_pivot2.to_csv('df_pivot2.csv')
# download the file to the download folder in my local drive
files.download('df_pivot2.csv')

# %%
import csv
with open('/content/df_pivot3.csv', newline='') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    data = []
    for row in csvreader:
        row_data = [float(x) for x in row]
        data.append(row_data)

for row in data:
    print(row)
# Out:
# [172416848.0, 176645104.0, 179140288.0, 181455936.0, 183368544.0, 185435040.0, 187428256.0, 188959808.0, 190703872.0, 193679040.0, 196683520.0, 199904176.0, 203652448.0, 207884368.0, 211988048.0, 216186992.0, 220030528.0, 223859408.0, 228131632.0, 232385536.0, 236833632.0, 241864304.0, 246532240.0, 251460320.0, 257080896.0, 261576624.0, 266068688.0, 271370496.0, 276104384.0, 280967834.0, 285502507.0, 406704.0, 813408.0, 1220112.0, 1630480.0, 2037184.0, 2462208.0, 2916544.0, 3381872.0, 3872848.0, 4385808.0, 4909760.0, 5433712.0, 5964992.0, 6499936.0, 7060528.0, 7635776.0, 8181712.0, 8720320.0, 9258928.0, 9775552.0, 10292176.0, 10783152.0, 11270464.0, 11746784.0, 12208448.0, 12673776.0, 13142768.0, 13608096.0, 14102736.0, 14604584.0, 15070878.0, 248525343.0, 255813635.0, 261676574.0, 264251613.0, 266964955.0, 270398135.0, 272993575.0, 276262813.0, 279660025.0, 282709560.0, 286200967.0, 289733668.0, 292810461.0, 296266021.0, 299957218.0, 304333387.0, 308734977.0, 313835187.0, 319409977.
# ...

# %%
def sliding_window(elements, window_size):

    if len(elements) <= window_size:
       return elements
    for i in range(len(elements)- window_size + 1):
        print(elements[i:i+window_size])
sliding_window(row, 35)
# Out:
# [172416848.0, 176645104.0, 179140288.0, 181455936.0, 183368544.0, 185435040.0, 187428256.0, 188959808.0, 190703872.0, 193679040.0, 196683520.0, 199904176.0, 203652448.0, 207884368.0, 211988048.0, 216186992.0, 220030528.0, 223859408.0, 228131632.0, 232385536.0, 236833632.0, 241864304.0, 246532240.0, 251460320.0, 257080896.0, 261576624.0, 266068688.0, 271370496.0, 276104384.0, 280967834.0, 285502507.0, 406704.0, 813408.0, 1220112.0, 1630480.0]
# [176645104.0, 179140288.0, 181455936.0, 183368544.0, 185435040.0, 187428256.0, 188959808.0, 190703872.0, 193679040.0, 196683520.0, 199904176.0, 203652448.0, 207884368.0, 211988048.0, 216186992.0, 220030528.0, 223859408.0, 228131632.0, 232385536.0, 236833632.0, 241864304.0, 246532240.0, 251460320.0, 257080896.0, 261576624.0, 266068688.0, 271370496.0, 276104384.0, 280967834.0, 285502507.0, 406704.0, 813408.0, 1220112.0, 1630480.0, 2037184.0]
# ...

# %%
import pandas as pd

def sliding_window(elements, window_size):
    if len(elements) <= window_size:
        return elements

    result = []
    for i in range(len(elements)- window_size + 1):
        result.append(elements[i:i+window_size])

    return pd.DataFrame(result)

# %%
new_df = sliding_window(row, 35)
new_df
# Out:
#                 0             1             2             3             4   \
# 0     1.724168e+08  1.766451e+08  1.791403e+08  1.814559e+08  1.833685e+08
# 1     1.766451e+08  1.791403e+08  1.814559e+08  1.833685e+08  1.854350e+08
# 2     1.791403e+08  1.814559e+08  1.833685e+08  1.854350e+08  1.874283e+08
# 3     1.814559e+08  1.833685e+08  1.854350e+08  1.874283e+08  1.889598e+08
# 4     1.833685e+08  1.854350e+08  1.874283e+08  1.889598e+08  1.907039e+08
# ...            ...           ...           ...           ...           ...
# 1449  2.895221e+10  2.920972e+10  2.943354e+10  2.966755e+10  2.989064e+10
# 1450  2.920972e+10  2.943354e+10  2.966755e+10  2.989064e+10  3.012267e+10
# 1451  2.943354e+10  2.966755e+10  2.989064e+10  3.012267e+10  3.034525e+10
# 1452  2.966755e+10  2.989064e+10  3.012267e+10  3.034525e+10  3.055916e+10
# 1453  2.989064e+10  3.012267e+10  3.034525e+10  3.055916e+10  6.270300e+10
#
# ...

# %%
print(new_df.columns)
# Out:
# RangeIndex(start=0, stop=35, step=1)

# %%
# Downloading my cleaned and merged data for big data analysis and power BI visualization
from google.colab import files
# save the file from dataframe to a csv format
new_df.to_csv('new_df.csv')
# download the file to the download folder in my local drive
files.download('new_df.csv')
